# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, auc, roc_curve, roc_auc_score

# %%
df = pd.read_csv("NEW Candidates Cleaned.csv")
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#    Unnamed: 0 geo_name  year    votes  vote_share  incumbent  winner  \
# 0        3244  Abilene  1996   3826.0        0.89        1.0       1
# 1        4719  Abilene  1996    451.0        0.11        0.0       0
# 2         530    Akron  2003  26967.0        0.71        1.0       1
# 3        1480    Akron  2003  11171.0        0.29        0.0       0
# 4         419    Akron  2011  31674.0        0.70        1.0       1
#
#    prob_democrat  prob_republican     pid_est  prob_male  prob_female  \
# 0       0.050000         0.950000  Republican        1.0          0.0
# 1       0.573265         0.426735     Unknown        1.0          0.0
# 2       1.000000         0.000000    Democrat        1.0          0.0
# 3       0.000000         1.000000  Republican        1.0          0.0
# 4       1.000000         0.000000    Democrat        1.0          0.0
#
#   gender_est  prob_black  prob_white  prob_hispanic  prob_asian  prob_other  \
# 0       Male        0.00        1.00            0.0         0.0         0.0
# 1       Male        0.03        0.97            0.0         0.0         0.0
# 2       Male        0.00        1.00            0.0         0.0         0.0
# 3       Male        0.58        0.41            0.0         0.0         0.0
# 4       Male        0.00        1.00            0.0         0.0         0.0
#
#     race_est  contributor.cfscore  percent_women  percent_white  \
# 0  Caucasian             1.020000       0.502459       0.798016
# 1  Caucasian            -0.145909       0.502459       0.798016
# 2  Caucasian            -0.850000       0.520664       0.657211
# 3      Black             0.550000       0.520664       0.657211
# 4  Caucasian            -0.362011       0.517043       0.619837
#
#    percent_black  percent_hispanic  percent_asian_american  candidate_count  \
# 0       0.080899          0.178764                0.101590                2
# 1       0.080899          0.178764                0.101590                2
# 2       0.293766          0.014515                0.022447                2
# 3       0.293766          0.014515                0.022447                2
# 4       0.313499          0.022048                0.030919                2
#
#    cpi_prevYear  unemployment_prevYear  pid_est_knn  gender_est_knn  \
# 0    152.383333                    5.6     1.000000             1.0
# 1    152.383333                    5.6     0.417135             1.0
# 2    179.866667                    5.8     0.000000             1.0
# 3    179.866667                    5.8     1.000000             1.0
# 4    218.076167                    9.6     0.000000             1.0
#
#    race_est_knn
# 0           2.0
# 1           2.0
# 2           2.0
# 3           1.0
# 4           2.0

# %% [markdown]
# # Should the Model Have the Incumbent Column?

# %% [markdown]
# ### Base Model Without Incumbent Column

# %%
categorical_features = ["pid_est", "gender_est", "race_est"]
numeric_features = ["candidate_count"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['pid_est', 'gender_est',
#                                                    'race_est']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['candidate_count'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

# %%
print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74       681
#            1       0.53      0.60      0.57       367
#
#     accuracy                           0.68      1048
#    macro avg       0.65      0.66      0.65      1048
# weighted avg       0.69      0.68      0.68      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)
roc_auc
# Out:
# 0.6593865408699341

# %%
plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Base Model With Incumbent Column

# %%
categorical_features = ["pid_est", "gender_est", "race_est", "incumbent"]
numeric_features = ["candidate_count"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['pid_est', 'gender_est',
#                                                    'race_est', 'incumbent']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['candidate_count'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

# %%
print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       681
#            1       0.77      0.78      0.77       367
#
#     accuracy                           0.84      1048
#    macro avg       0.82      0.82      0.82      1048
# weighted avg       0.84      0.84      0.84      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)
roc_auc
# Out:
# 0.8244067267642151

# %%
plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ### Varying Number of Trees

# %%
model = RandomForestClassifier(n_estimators=10, random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       681
#            1       0.77      0.77      0.77       367
#
#     accuracy                           0.84      1048
#    macro avg       0.82      0.82      0.82      1048
# weighted avg       0.84      0.84      0.84      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %%
model = RandomForestClassifier(n_estimators=50, random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       681
#            1       0.76      0.78      0.77       367
#
#     accuracy                           0.84      1048
#    macro avg       0.82      0.82      0.82      1048
# weighted avg       0.84      0.84      0.84      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %%
model = RandomForestClassifier(n_estimators=1000, random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       681
#            1       0.77      0.78      0.78       367
#
#     accuracy                           0.84      1048
#    macro avg       0.83      0.83      0.83      1048
# weighted avg       0.84      0.84      0.84      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Varying Maximum Number of Features

# %%
model = RandomForestClassifier(max_features=None, random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       681
#            1       0.77      0.77      0.77       367
#
#     accuracy                           0.84      1048
#    macro avg       0.82      0.82      0.82      1048
# weighted avg       0.84      0.84      0.84      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Varying Minimum Leaf Node Size

# %%
model = RandomForestClassifier(min_samples_leaf=5, random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %%
model = RandomForestClassifier(min_samples_leaf=10, random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Varying Maximum Tree Depth

# %%
model = RandomForestClassifier(max_depth=10, random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       681
#            1       0.77      0.78      0.77       367
#
#     accuracy                           0.84      1048
#    macro avg       0.82      0.83      0.82      1048
# weighted avg       0.84      0.84      0.84      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %%
model = RandomForestClassifier(max_depth=5, random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Varying Split Criterion

# %%
model = RandomForestClassifier(criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88       681
#            1       0.77      0.78      0.77       367
#
#     accuracy                           0.84      1048
#    macro avg       0.82      0.83      0.82      1048
# weighted avg       0.84      0.84      0.84      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Combination of Best Hyperparameters

# %%
#n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy"
model = RandomForestClassifier(n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)

Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# # Testing Feature Columns

# %%
df.head(5)
# Out:
#    Unnamed: 0 geo_name  year    votes  vote_share  incumbent  winner  \
# 0        3244  Abilene  1996   3826.0        0.89        1.0       1
# 1        4719  Abilene  1996    451.0        0.11        0.0       0
# 2         530    Akron  2003  26967.0        0.71        1.0       1
# 3        1480    Akron  2003  11171.0        0.29        0.0       0
# 4         419    Akron  2011  31674.0        0.70        1.0       1
#
#    prob_democrat  prob_republican     pid_est  prob_male  prob_female  \
# 0       0.050000         0.950000  Republican        1.0          0.0
# 1       0.573265         0.426735     Unknown        1.0          0.0
# 2       1.000000         0.000000    Democrat        1.0          0.0
# 3       0.000000         1.000000  Republican        1.0          0.0
# 4       1.000000         0.000000    Democrat        1.0          0.0
#
#   gender_est  prob_black  prob_white  prob_hispanic  prob_asian  prob_other  \
# 0       Male        0.00        1.00            0.0         0.0         0.0
# 1       Male        0.03        0.97            0.0         0.0         0.0
# 2       Male        0.00        1.00            0.0         0.0         0.0
# 3       Male        0.58        0.41            0.0         0.0         0.0
# 4       Male        0.00        1.00            0.0         0.0         0.0
#
#     race_est  contributor.cfscore  percent_women  percent_white  \
# 0  Caucasian             1.020000       0.502459       0.798016
# 1  Caucasian            -0.145909       0.502459       0.798016
# 2  Caucasian            -0.850000       0.520664       0.657211
# 3      Black             0.550000       0.520664       0.657211
# 4  Caucasian            -0.362011       0.517043       0.619837
#
#    percent_black  percent_hispanic  percent_asian_american  candidate_count  \
# 0       0.080899          0.178764                0.101590                2
# 1       0.080899          0.178764                0.101590                2
# 2       0.293766          0.014515                0.022447                2
# 3       0.293766          0.014515                0.022447                2
# 4       0.313499          0.022048                0.030919                2
#
#    cpi_prevYear  unemployment_prevYear  pid_est_knn  gender_est_knn  \
# 0    152.383333                    5.6     1.000000             1.0
# 1    152.383333                    5.6     0.417135             1.0
# 2    179.866667                    5.8     0.000000             1.0
# 3    179.866667                    5.8     1.000000             1.0
# 4    218.076167                    9.6     0.000000             1.0
#
#    race_est_knn
# 0           2.0
# 1           2.0
# 2           2.0
# 3           1.0
# 4           2.0

# %% [markdown]
# ### Best Model with KNN Features

# %%
categorical_features = ["incumbent"]
numeric_features = ["candidate_count", "pid_est_knn", "gender_est_knn", "race_est_knn"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['incumbent']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['candidate_count',
#                                                    'pid_est_knn',
#                                                    'gender_est_knn',
#                                                    'race_est_knn'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(criterion='entropy', max_depth=5,
#                                         min_samples_leaf=5, n_estimators=1000,
#                                         random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Best Model with Numeric Features

# %%
categorical_features = ["incumbent"]
numeric_features = ["candidate_count", "prob_democrat", "prob_republican", "prob_male", "prob_female", "prob_black",
                    "prob_white", "prob_hispanic", "prob_asian", "prob_other"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['incumbent']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['candidate_count',
#                                                    'prob_democrat',
#                                                    'prob_republican',
#                                                    'prob_male', 'prob_female',
#                                                    'prob_black', 'prob_white',
#                                                    'prob_hispanic',
#                                                    'prob_asian',
#                                                    'prob_other'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(criterion='entropy', max_depth=5,
#                                         min_samples_leaf=5, n_estimators=1000,
#                                         random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Best Model with Contributor Ideology Score

# %%
categorical_features = ["pid_est", "gender_est", "race_est", "incumbent"]
numeric_features = ["candidate_count", "contributor.cfscore"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['pid_est', 'gender_est',
#                                                    'race_est', 'incumbent']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['candidate_count',
#                                                    'contributor.cfscore'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(criterion='entropy', max_depth=5,
#                                         min_samples_leaf=5, n_estimators=1000,
#                                         random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Best Model with Population Gender

# %%
categorical_features = ["pid_est", "gender_est", "race_est", "incumbent"]
numeric_features = ["candidate_count", "percent_women"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['pid_est', 'gender_est',
#                                                    'race_est', 'incumbent']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['candidate_count',
#                                                    'percent_women'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(criterion='entropy', max_depth=5,
#                                         min_samples_leaf=5, n_estimators=1000,
#                                         random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Best Model with Population Race

# %%
categorical_features = ["pid_est", "gender_est", "race_est", "incumbent"]
numeric_features = ["candidate_count", "percent_black", "percent_white",
                    "percent_hispanic", "percent_asian_american"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['pid_est', 'gender_est',
#                                                    'race_est', 'incumbent']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['candidate_count',
#                                                    'percent_black',
#                                                    'percent_white',
#                                                    'percent_hispanic',
#                                                    'percent_asian_american'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(criterion='entropy', max_depth=5,
#                                         min_samples_leaf=5, n_estimators=1000,
#                                         random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Best Model with Prev Year's CPI

# %%
categorical_features = ["pid_est", "gender_est", "race_est", "incumbent"]
numeric_features = ["candidate_count", "cpi_prevYear"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['pid_est', 'gender_est',
#                                                    'race_est', 'incumbent']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['candidate_count',
#                                                    'cpi_prevYear'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(criterion='entropy', max_depth=5,
#                                         min_samples_leaf=5, n_estimators=1000,
#                                         random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# ### Best Model with Prev Year's Unemployment

# %%
categorical_features = ["pid_est", "gender_est", "race_est", "incumbent"]
numeric_features = ["candidate_count", "unemployment_prevYear"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['pid_est', 'gender_est',
#                                                    'race_est', 'incumbent']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['candidate_count',
#                                                    'unemployment_prevYear'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(criterion='entropy', max_depth=5,
#                                         min_samples_leaf=5, n_estimators=1000,
#                                         random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')

# %% [markdown]
# # Final Random Forest Model

# %%
categorical_features = ["incumbent"]
numeric_features = ["pid_est_knn", "gender_est_knn", "race_est_knn", "candidate_count"]
selected_features = categorical_features + numeric_features

X = df[selected_features]
Y = df["winner"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
ohe = OneHotEncoder()
std = StandardScaler()

ct = make_column_transformer(
    (ohe, categorical_features),
    (std, numeric_features),
    remainder = 'passthrough'
)

model = RandomForestClassifier(n_estimators=1000, max_features="sqrt", min_samples_leaf=5, max_depth=5, criterion="entropy", random_state=42)

pipeline = make_pipeline(ct, model)
pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['incumbent']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['pid_est_knn',
#                                                    'gender_est_knn',
#                                                    'race_est_knn',
#                                                    'candidate_count'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(criterion='entropy', max_depth=5,
#                                         min_samples_leaf=5, n_estimators=1000,
#                                         random_state=42))])

# %%
Y_pred = pipeline.predict(X_test)

print("\nTest Set Evaluation:")
print(classification_report(Y_test, Y_pred))
# Out:
# Test Set Evaluation:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88       681
#            1       0.78      0.80      0.79       367
#
#     accuracy                           0.85      1048
#    macro avg       0.83      0.84      0.84      1048
# weighted avg       0.85      0.85      0.85      1048

# %%
plt.figure(figsize=(8, 6))
cm = confusion_matrix(Y_test, Y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('confusion_matrix.png')

# %%
roc_auc = roc_auc_score(Y_test, Y_pred)

plt.figure(figsize=(10, 8))
plt.subplot(2, 1, 1)
fpr, tpr, _ = roc_curve(Y_test, Y_pred)
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Decision Trees')
plt.legend(loc='lower right')
